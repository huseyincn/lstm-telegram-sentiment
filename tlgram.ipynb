# %%
import tensorflow as tf

new_model = tf.keras.models.load_model('telegramlstm.keras')

# Show the model architecture
new_model.summary()
# Out:
# 2024-05-04 16:38:59.451961: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-05-04 16:38:59.454495: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-05-04 16:38:59.495291: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-04 16:39:00.339202: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/usern/.conda/envs/py311conda/lib/python3.11/site-packages/keras/src/layers/core/embedding.py:86: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# ...

# %%
import tensorflow as tf
import keras
print(tf.__version__)
print(keras.__version__)
print(tf.keras.__version__)
# Out:
# 2.16.1
# 3.2.1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 5
#       3 print(tf.__version__)
#       4 print(keras.__version__)
# ----> 5 print(tf.keras.__version__)
#
# AttributeError: module 'keras._tf_keras.keras' has no attribute '__version__'
